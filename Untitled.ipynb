# %%
import pandas as pd # lese data fra csv-fil og bruke DataFrames
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

df = pd.read_csv('skostr_hoyde-2 (2).csv')

# 2. Extract your columns (skostr as X, hoyde as y)
X = df[['skostr']]  
y = df['hoyde']

# 3. Fit the linear regression model
model = LinearRegression()
model.fit(X, y)

# 4. Generate the regression line predictions
y_pred = model.predict(X)

# 5. Output the calculations
print(f"Slope (m): {model.coef_[0]:.4f}")
print(f"Intercept (c): {model.intercept_:.4f}")
print(f"Line Equation: y = {model.coef_[0]:.4f} * x + {model.intercept_:.4f}")

# 6. Plot your dataset and regression line
plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='blue', s=100, label='Actual Data Points') 
plt.plot(X, y_pred, color='red', linewidth=2, label='Best-Fit Regression Line') 

# Labels matching your dataset
plt.title('Linear Regression: Skostr vs. Hoyde', fontsize=14)
plt.xlabel('Skostr', fontsize=12)
plt.ylabel('Hoyde cm', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()

# Display the plot
plt.show()
# Out:
# Slope (m): 5.1017
# Intercept (c): -34.5556
# Line Equation: y = 5.1017 * x + -34.5556
